# %% [markdown]
# # ICS 3202 – Artificial Intelligence
# ## Practical Exercise 2: Data Cleaning
# ### Evidence of Teamwork and Division of Tasks
#
# ---
#
# ## Group Members
# Austin - 181807
# Adrian - 178619
# Jeremy - 190280
#
# ---
#
# ## Division of Tasks
#
# ### Austin – Questions 1–4
# Austin was responsible for completing Questions 1 to 4:
#
# - **Question 1:** Downloading and uploading the Airplane Crashes Dataset from Kaggle.
# - **Question 2:** Determining the number of rows and columns in the dataset.
# - **Question 3:** Displaying the last 75 rows of the dataset.
# - **Question 4:** Identifying the most appropriate method for treating missing data in each column and providing justifications.
#
# ### Adrian – Questions 5–7
# Adrian was responsible for completing Questions 5 to 7:
#
# - **Question 5:** Creating the `fatality_locations` dataframe with the required columns.
# - **Question 6:** Determining the date with the highest recorded number of fatalities.
# - **Question 7:** Comparing passengers aboard with fatalities and determining the number of crashes with no fatalities.
#
# ### Jeremy – Questions 8–10
# Jeremy was responsible for completing Questions 8 to 10:
#
# - **Question 8:** Splitting the `Location` column into regions and states/countries.
# - **Question 9:** Ordering the dataframe by fatalities from highest to lowest and selecting the first 100 records.
# - **Question 10:** Generating a pie chart showing the distribution of the top 25 fatalities per country/U.S. State.
#
# ---
#
# ## Team Collaboration
#
# The assignment was divided among the three group members to ensure that all members contributed to the completion of the practical exercise. Each member worked on their assigned questions and contributed their completed work to the group's final Jupyter Notebook.
#
# After completing the individual sections, the group members reviewed and integrated their work into the final submission to ensure consistency, completeness, and correct formatting.
#
# ### Contribution Summary
#
# - **Austin:** Questions 1–4
# - **Adrian:** Questions 5–7
# - **Jeremy:** Questions 8–10
#
# ---
#
# ## Teamwork Evidence
#
# The groupwork was carried out collaboratively, with each member responsible for a specific section of the practical exercise.
#
# ---
